# %%
from BGS_Polygon_Scraper import BGS
from shapely.geometry import Polygon

# to play with the module in real time
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Polygon download

# %%
easting_point_list = [419058, 419150, 419152, 419055]
northing_point_list = [438832, 438832, 438779, 438781]
polygon_geom = Polygon(zip(easting_point_list, northing_point_list))

# %%
XYZ = BGS.boreholes_from_polygon(polygon_geom)
# Out:
# C:\Users\JON80843\Anaconda3\lib\site-packages\pyproj\crs\crs.py:131: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   in_crs_string = _prepare_from_proj_string(in_crs_string)

# %%
BGS.download_images(XYZ.image_paths, r'.tmp')
# Out:
# pdf/SE13NE1244.pdf SE13NE1244
# pdf/SE13NE1228.pdf SE13NE1228
# pdf/SE13NE1229.pdf SE13NE1229
# pdf/SE13NE1236.pdf SE13NE1236
# pdf/SE13NE1249.pdf SE13NE1249
# pdf/SE13NE1247.pdf SE13NE1247
# pdf/SE13NE1251.pdf SE13NE1251
# pdf/SE13NE1233.pdf SE13NE1233
# pdf/SE13NE1241.pdf SE13NE1241
# pdf/SE13NE1257.pdf SE13NE1257
# pdf/SE13NE1226.pdf SE13NE1226
# pdf/SE13NE1231.pdf SE13NE1231
# pdf/SE13NE1240.pdf SE13NE1240
# pdf/SE13NE1246.pdf SE13NE1246
# pdf/SE13NE1252.pdf SE13NE1252
# pdf/SE13NE1253.pdf SE13NE1253
# pdf/SE13NE1243.pdf SE13NE1243
# pdf/SE13NE1255.pdf SE13NE1255
# pdf/SE13NE1223.pdf SE13NE1223
# pdf/SE13NE1225.pdf SE13NE1225
# pdf/SE13NE1248.pdf SE13NE1248
# pdf/SE13NE1224.pdf SE13NE1224
# pdf/SE13NE1230.pdf SE13NE1230
# pdf/SE13NE1235.pdf SE13NE1235
# pdf/SE13NE1237.pdf SE13NE1237
# pdf/SE13NE1258.pdf SE13NE1258
# pdf/SE13NE1250.pdf SE13NE1250
# pdf/SE13NE1227.pdf SE13NE1227
# pdf/SE13NE1239.pdf SE13NE1239
# pdf/SE13NE1242.pdf SE13NE1242
# pdf/SE13NE1234.pdf SE13NE1234
# ...

# %%
import glob
files = glob.glob(".tmp" + '/**/*.png', recursive=True)
files
# Out:
# ['.tmp\\SE13NE1223_1.png',
#  '.tmp\\SE13NE1223_2.png',
#  '.tmp\\SE13NE1223_3.png',
#  '.tmp\\SE13NE1223_4.png',
#  '.tmp\\SE13NE1223_5.png',
#  '.tmp\\SE13NE1223_6.png',
#  '.tmp\\SE13NE1224_1.png',
#  '.tmp\\SE13NE1224_2.png',
#  '.tmp\\SE13NE1224_3.png',
#  '.tmp\\SE13NE1224_4.png',
#  '.tmp\\SE13NE1224_5.png',
#  '.tmp\\SE13NE1225_1.png',
#  '.tmp\\SE13NE1225_2.png',
#  '.tmp\\SE13NE1225_3.png',
#  '.tmp\\SE13NE1225_4.png',
#  '.tmp\\SE13NE1225_5.png',
#  '.tmp\\SE13NE1226_1.png',
#  '.tmp\\SE13NE1226_2.png',
#  '.tmp\\SE13NE1226_3.png',
#  '.tmp\\SE13NE1226_4.png',
#  '.tmp\\SE13NE1226_5.png',
#  '.tmp\\SE13NE1227_1.png',
#  '.tmp\\SE13NE1227_2.png',
#  '.tmp\\SE13NE1227_3.png',
#  '.tmp\\SE13NE1227_4.png',
#  '.tmp\\SE13NE1227_5.png',
#  '.tmp\\SE13NE1227_6.png',
#  '.tmp\\SE13NE1228_1.png',
#  '.tmp\\SE13NE1228_2.png',
#  '.tmp\\SE13NE1228_3.png',
#  '.tmp\\SE13NE1228_4.png',
#  '.tmp\\SE13NE1228_5.png',
#  '.tmp\\SE13NE1229_1.png',
#  '.tmp\\SE13NE1229_2.png',
# ...

# %%
BGS.download_images(XYZ.image_paths, r'./.tmp')
